# %% [markdown]
# ## Kafka Consumer

# %%
import json
import uuid
import os
import json
from dotenv import load_dotenv
from pathlib import Path
from kafka import KafkaConsumer
from kafka import TopicPartition
from faker import Faker
from time import sleep

# %%
dotenv_path = Path('/resources/.env')
load_dotenv(dotenv_path=dotenv_path)
# Out:
# True

# %%
kafka_host = os.getenv('KAFKA_HOST')

# %%
kafka_topic_partition = "Data_Transaksi_Keuangan_E-commerce"

# %%
# To consume latest messages and auto-commit offsets

consumer = KafkaConsumer(kafka_topic_partition,
                         group_id='consumer-group_0',
                         bootstrap_servers=[f'{kafka_host}:9092'])

# %%
count = 0  # Inisialisasi penghitung pesan

for message in consumer:
    print("nomor pesan ke:", count)
    # Cetak detail pesan
    print("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                         message.offset, message.key,
                                         message.value))
    
    # Tambah penghitung setiap kali pesan diterima
    count += 1
    # Cetak jumlah total pesan setelah selesai (atau di bagian lain sesuai kebutuhan)
    print("\n")
# Out:
# nomor pesan ke: 0
# Data_Transaksi_Keuangan_E-commerce:0:0: key=b'87b5df14-f330-474f-bbcd-e36facb7e9eb' value=b'{"transaction_id": "87b5df14-f330-474f-bbcd-e36facb7e9eb", "timestamp": "2024-03-29T05:53:27", "user_id": "ec062139-f8de-485e-8cfa-a0932758cf2e", "merchant_id": "773a6143-ff5a-4813-8001-370fbe9f9624", "amount": 90462.24, "age": 64, "gender": "Female", "phone_number": "196.162.9006", "email": "bstevens@example.net", "currency": "USD", "location": "Millerfurt", "country": "Bahamas", "payment_method": "PayPal", "product_id": "d34153c6-26be-49fa-b334-23703e088be5", "product_category": "Office and School Supplies", "quantity": 36, "discount": 97, "tax": 46, "shipping_cost": 53, "total_cost": 90464.24}'
#
#
# nomor pesan ke: 1
# Data_Transaksi_Keuangan_E-commerce:0:1: key=b'ce2f111a-96db-4cdf-81e8-aff68bf3dff9' value=b'{"transaction_id": "ce2f111a-96db-4cdf-81e8-aff68bf3dff9", "timestamp": "2024-06-10T11:40:40", "user_id": "0b755319-f78b-40dd-906a-de1803e7d947", "merchant_id": "4bae1ba6-4b51-4ef9-b384-258ce2c4ab4f", "amount": 40967.81, "age": 55, "gender": "Male", "phone_number": "(685)845-6875x15004", "email": "saragalloway@example.net", "currency": "SOS", "location": "West Loriton", "country": "Rwanda", "payment_method": "Debit Card", "product_id": "35a7e1ee-546b-4340-9431-c996472c8940", "product_category": "Fashion and Accessories", "quantity": 1, "discount": 5, "tax": 61, "shipping_cost": 95, "total_cost": 41118.81}'
#
#
# nomor pesan ke: 2
# Data_Transaksi_Keuangan_E-commerce:0:2: key=b'701054d8-44fb-4b57-a11a-bc68cbc1a95b' value=b'{"transaction_id": "701054d8-44fb-4b57-a11a-bc68cbc1a95b", "timestamp": "2024-04-21T07:39:47", "user_id": "8c3cfe5b-9324-4537-bda3-475245ef2068", "merchant_id": "92c8a012-e8fe-46ca-a238-bf438dc28ea7", "amount": 62671.82, "age": 51, "gender": "Male", "phone_number": "875-270-4671", "email": "heatherryan@example.net", "currency": "KHR", "location": "South Michellestad", "country": "Puerto Rico", "payment_method": "Local Bank Transfer", "product_id": "283f6088-2581-4a39-adba-c08fec67b636", "product_category": "Fashion and Accessories", "quantity": 20, "discount": 37, "tax": 90, "shipping_cost": 50, "total_cost": 62774.82}'
#
#
# nomor pesan ke: 3
# Data_Transaksi_Keuangan_E-commerce:0:3: key=b'63f233b6-3b4f-49f0-ab98-11db8a15f2a4' value=b'{"transaction_id": "63f233b6-3b4f-49f0-ab98-11db8a15f2a4", "timestamp": "2024-07-24T16:06:40", "user_id": "aa56d941-18ea-43e7-94c8-0b071d4ebdeb", "merchant_id": "067ee1fb-fd15-4bd9-83bb-0f8b9acc315e", "amount": 63609.59, "age": 26, "gender": "Female", "phone_number": "+1-919-262-9704x3137", "email": "jason01@example.com", "currency": "JPY", "location": "New Nathan", "country": "Pakistan", "payment_method": "Credit Card", "product_id": "72cc4103-5cf2-4288-9f41-fc1533e4d0eb", "product_category": "Real Estate and Property", "quantity": 41, "discount": 88, "tax": 70, "shipping_cost": 51, "total_cost": 63642.59}'
#
#
# nomor pesan ke: 4
# Data_Transaksi_Keuangan_E-commerce:0:4: key=b'ac6c8775-1530-4218-92e6-42fd1d52e8ba' value=b'{"transaction_id": "ac6c8775-1530-4218-92e6-42fd1d52e8ba", "timestamp": "2024-10-24T10:05:55", "user_id": "e5758a5f-b74b-4c62-8320-226c9cf324a0", "merchant_id": "f7fcb65b-d676-47b6-94ec-e9f379625c93", "amount": 82100.23, "age": 46, "gender": "Female", "phone_number": "789.289.8939x64126", "email": "jenniferbriggs@example.com", "currency": "JPY", "location": "Collinstown", "country": "Malawi", "payment_method": "Local Bank Transfer", "product_id": "e695e893-1c66-49ac-9061-1aa736961340", "product_category": "Food and Beverages", "quantity": 31, "discount": 76, "tax": 29, "shipping_cost": 1, "total_cost": 82054.23}'
#
#
# nomor pesan ke: 5
# Data_Transaksi_Keuangan_E-commerce:0:5: key=b'026c5700-dbf0-4860-89a8-d0bd51e0258c' value=b'{"transaction_id": "026c5700-dbf0-4860-89a8-d0bd51e0258c", "timestamp": "2024-02-18T19:28:46", "user_id": "a83d641d-f841-49e0-8b3f-268a22fa64cf", "merchant_id": "c4a68a23-a917-493d-b40d-fc71594cec40", "amount": 44484.06, "age": 57, "gender": "Female", "phone_number": "280.560.1384x5202", "email": "ytaylor@example.net", "currency": "XOF", "location": "East Michelle", "country": "Turks and Caicos Islands", "payment_method": "Foreign Bank Transfer", "product_id": "458f0c8c-01ec-4212-8a84-bbc174babb8e", "product_category": "Automotive", "quantity": 10, "discount": 48, "tax": 47, "shipping_cost": 61, "total_cost": 44544.06}'
#
#
# nomor pesan ke: 6
# Data_Transaksi_Keuangan_E-commerce:0:6: key=b'7b677a58-5d2f-45ee-b18c-df3f999e7790' value=b'{"transaction_id": "7b677a58-5d2f-45ee-b18c-df3f999e7790", "timestamp": "2024-05-02T22:17:10", "user_id": "75ef2bd0-f887-4374-b080-145db28ac650", "merchant_id": "809804e4-97e7-4821-b5fa-8e053e1210b8", "amount": 3201.03, "age": 45, "gender": "Male", "phone_number": "405.596.7816x96527", "email": "zpoole@example.org", "currency": "CVE", "location": "New Chadfort", "country": "American Samoa", "payment_method": "Local Bank Transfer", "product_id": "11f1a46e-6e51-450e-b192-22a914c19a14", "product_category": "Automotive", "quantity": 30, "discount": 94, "tax": 62, "shipping_cost": 30, "total_cost": 3199.03}'
#
#
# nomor pesan ke: 7
# Data_Transaksi_Keuangan_E-commerce:0:7: key=b'3500d3fe-f614-424c-8aeb-920929de6a55' value=b'{"transaction_id": "3500d3fe-f614-424c-8aeb-920929de6a55", "timestamp": "2024-09-25T10:35:09", "user_id": "9b3d1a32-b49e-4309-8c86-f81fb03502d9", "merchant_id": "4cfef93b-518c-431d-9ac5-bfaadea51b53", "amount": 16302.18, "age": 41, "gender": "Female", "phone_number": "001-508-216-2607x1754", "email": "xavery@example.com", "currency": "ZWD", "location": "Dunnland", "country": "Venezuela", "payment_method": "PayPal", "product_id": "6088597b-25f7-4674-a195-0a65129d9fc3", "product_category": "Baby and Kids Products", "quantity": 40, "discount": 37, "tax": 30, "shipping_cost": 15, "total_cost": 16310.18}'
#
#
# nomor pesan ke: 8
# Data_Transaksi_Keuangan_E-commerce:0:8: key=b'b0c96800-ccf1-4a79-baaa-bc399f8dcdfb' value=b'{"transaction_id": "b0c96800-ccf1-4a79-baaa-bc399f8dcdfb", "timestamp": "2024-05-16T13:26:54", "user_id": "adfa2bb7-29bd-4b39-abfc-d98ab9d1139f", "merchant_id": "7a018b50-9433-44f0-b397-a31930ff42cf", "amount": 56703.74, "age": 20, "gender": "Male", "phone_number": "(196)141-4921", "email": "lauren61@example.com", "currency": "XPF", "location": "Port Brentchester", "country": "Botswana", "payment_method": "Debit Card", "product_id": "f3becea8-d257-4c11-b5b6-df784e81e917", "product_category": "Baby and Kids Products", "quantity": 48, "discount": 54, "tax": 77, "shipping_cost": 66, "total_cost": 56792.74}'
#
#
# nomor pesan ke: 9
# Data_Transaksi_Keuangan_E-commerce:0:9: key=b'6d797688-dc90-4eeb-b504-2930e701ad80' value=b'{"transaction_id": "6d797688-dc90-4eeb-b504-2930e701ad80", "timestamp": "2024-08-03T22:52:03", "user_id": "cdb299df-bc94-458f-9fd9-e307df83cc6f", "merchant_id": "c6905913-c6e8-4997-810a-da27878fb158", "amount": 98975.61, "age": 51, "gender": "Male", "phone_number": "969.202.1973", "email": "bradfordbrenda@example.org", "currency": "NGN", "location": "Johnsonhaven", "country": "Svalbard & Jan Mayen Islands", "payment_method": "Debit Card", "product_id": "210677b6-3f16-47fc-9d55-87a50ed7726f", "product_category": "Sports and Outdoors", "quantity": 20, "discount": 4, "tax": 5, "shipping_cost": 65, "total_cost": 99041.61}'
#
#
# nomor pesan ke: 10
# Data_Transaksi_Keuangan_E-commerce:0:10: key=b'da5456fd-e3fe-4166-b095-53c63b2c8aa5' value=b'{"transaction_id": "da5456fd-e3fe-4166-b095-53c63b2c8aa5", "timestamp": "2024-08-27T04:39:11", "user_id": "08468514-c1f1-4021-bca1-20517de8df95", "merchant_id": "cdff801a-60e4-47fc-89d6-e627796d83a7", "amount": 42919.76, "age": 32, "gender": "Female", "phone_number": "044-538-5534", "email": "marvin69@example.org", "currency": "HRK", "location": "Port Morgan", "country": "Nepal", "payment_method": "Local Bank Transfer", "product_id": "837b19e8-1cc7-4da7-8eb4-05b22185d278", "product_category": "Office and School Supplies", "quantity": 31, "discount": 28, "tax": 35, "shipping_cost": 97, "total_cost": 43023.76}'
#
#
# nomor pesan ke: 11
# Data_Transaksi_Keuangan_E-commerce:0:11: key=b'483eb111-1254-4550-a548-7aa13e711d09' value=b'{"transaction_id": "483eb111-1254-4550-a548-7aa13e711d09", "timestamp": "2024-02-24T14:26:10", "user_id": "e0a26cfd-02eb-4f05-ae5b-802cf124ace9", "merchant_id": "39153269-93af-4500-85a8-5c1b5dcabbc6", "amount": 70888.66, "age": 53, "gender": "Female", "phone_number": "(617)572-5938x6701", "email": "slopez@example.net", "currency": "MVR", "location": "North Pamela", "country": "Finland", "payment_method": "Local Bank Transfer", "product_id": "00543d2e-ecaa-4dd3-9f2f-a13012857bbe", "product_category": "Health and Beauty", "quantity": 11, "discount": 60, "tax": 68, "shipping_cost": 78, "total_cost": 70974.66}'
#
#
# nomor pesan ke: 12
# Data_Transaksi_Keuangan_E-commerce:0:12: key=b'48061d7b-0309-4468-99ee-debb027805e1' value=b'{"transaction_id": "48061d7b-0309-4468-99ee-debb027805e1", "timestamp": "2024-05-08T03:59:51", "user_id": "c2fcc83f-0030-4dc3-ab4d-2621ffc7cf67", "merchant_id": "407b8d0f-81b5-4386-a559-db877d14fbd0", "amount": 82047.9, "age": 28, "gender": "Male", "phone_number": "949.329.0788", "email": "allengeorge@example.net", "currency": "NGN", "location": "Jimport", "country": "Israel", "payment_method": "Credit Card", "product_id": "f6ea2b29-e5f4-409a-8590-61117487c00e", "product_category": "Services and Consultancy", "quantity": 48, "discount": 11, "tax": 47, "shipping_cost": 73, "total_cost": 82156.9}'
#
#
# nomor pesan ke: 13
# Data_Transaksi_Keuangan_E-commerce:0:13: key=b'53136c54-258e-484e-b06f-e85d4ae4394e' value=b'{"transaction_id": "53136c54-258e-484e-b06f-e85d4ae4394e", "timestamp": "2024-04-19T07:39:45", "user_id": "a7715496-3a41-49dd-863e-6aa457f6b3b3", "merchant_id": "6b2d4818-4cfb-41f5-9190-f39586af63c9", "amount": 41937.94, "age": 55, "gender": "Male", "phone_number": "(514)798-3770x527", "email": "evansamy@example.com", "currency": "LKR", "location": "South Michaelbury", "country": "Niue", "payment_method": "Credit Card", "product_id": "8249af2b-761a-4777-aaca-2b004ec145ce", "product_category": "Home and Furniture", "quantity": 8, "discount": 92, "tax": 83, "shipping_cost": 0, "total_cost": 41928.94}'
#
#
# nomor pesan ke: 14
# Data_Transaksi_Keuangan_E-commerce:0:14: key=b'ca62332a-e385-43dc-9142-bc64d3665967' value=b'{"transaction_id": "ca62332a-e385-43dc-9142-bc64d3665967", "timestamp": "2024-10-12T12:12:11", "user_id": "ee0024f8-1109-4906-ac4a-c923a2256a33", "merchant_id": "eab38fbf-d09a-48fb-976b-da995a72bf8c", "amount": 65726.86, "age": 55, "gender": "Female", "phone_number": "214.491.6228", "email": "angela33@example.org", "currency": "SCR", "location": "Lake Steven", "country": "Israel", "payment_method": "Foreign Bank Transfer", "product_id": "313163a2-975a-4efa-8e46-392c870d9325", "product_category": "Automotive", "quantity": 49, "discount": 33, "tax": 82, "shipping_cost": 22, "total_cost": 65797.86}'
#
#
# nomor pesan ke: 15
# Data_Transaksi_Keuangan_E-commerce:0:15: key=b'218f9fa3-5dfc-4601-9248-dfd195412086' value=b'{"transaction_id": "218f9fa3-5dfc-4601-9248-dfd195412086", "timestamp": "2024-05-28T03:17:32", "user_id": "837d44c3-1cc3-4099-a628-85853e229c5b", "merchant_id": "f3e334b7-7eb7-4fe4-a033-83154ea90739", "amount": 63387.5, "age": 56, "gender": "Female", "phone_number": "+1-293-568-6910x4863", "email": "sanchezcorey@example.org", "currency": "MXN", "location": "Franklinton", "country": "Chad", "payment_method": "Local Bank Transfer", "product_id": "7105c5b6-1bd9-4cd5-9773-873823999b5e", "product_category": "Baby and Kids Products", "quantity": 13, "discount": 83, "tax": 24, "shipping_cost": 8, "total_cost": 63336.5}'
#
#
# nomor pesan ke: 16
# Data_Transaksi_Keuangan_E-commerce:0:16: key=b'6cabd4e7-aa6b-46b7-87bc-8c0d4576a1ef' value=b'{"transaction_id": "6cabd4e7-aa6b-46b7-87bc-8c0d4576a1ef", "timestamp": "2024-01-25T21:53:04", "user_id": "e60fb479-26d5-4a77-b1c3-9ff22b596b3d", "merchant_id": "4082c4cc-94f4-4d59-98da-bf48fc9690f6", "amount": 28642.11, "age": 44, "gender": "Male", "phone_number": "001-750-674-9422x074", "email": "csoto@example.org", "currency": "BMD", "location": "Lake Michaelshire", "country": "Philippines", "payment_method": "Credit Card", "product_id": "69b1c718-4663-4ea4-bd1e-e8a5552a6dfd", "product_category": "Electronics and Gadgets", "quantity": 39, "discount": 24, "tax": 51, "shipping_cost": 43, "total_cost": 28712.11}'
#
#
# nomor pesan ke: 17
# Data_Transaksi_Keuangan_E-commerce:0:17: key=b'c64c85e0-0b22-43dc-a784-29385d6614d7' value=b'{"transaction_id": "c64c85e0-0b22-43dc-a784-29385d6614d7", "timestamp": "2024-09-27T05:22:24", "user_id": "b022e79b-56c1-495f-b91e-279edce3a788", "merchant_id": "5681abbb-f9de-4745-a70d-0880fd694ba6", "amount": 74425.84, "age": 29, "gender": "Male", "phone_number": "227.054.3305x44033", "email": "travisharris@example.net", "currency": "COP", "location": "Brendabury", "country": "South Africa", "payment_method": "Foreign Bank Transfer", "product_id": "dbac61d7-5063-4251-9e95-aa099b5664a2", "product_category": "Digital Products and Services", "quantity": 43, "discount": 97, "tax": 76, "shipping_cost": 82, "total_cost": 74486.84}'
#
#
# nomor pesan ke: 18
# Data_Transaksi_Keuangan_E-commerce:0:18: key=b'2d48bb83-4842-4be5-a7c2-48e6678d57db' value=b'{"transaction_id": "2d48bb83-4842-4be5-a7c2-48e6678d57db", "timestamp": "2024-08-15T23:50:51", "user_id": "8a9b1dda-0ed2-4518-8a7c-6c1d54c7e3dd", "merchant_id": "2ff20c13-0d3d-4e64-91fc-ecf9b8d912f5", "amount": 10560.73, "age": 36, "gender": "Male", "phone_number": "618-083-5884x46430", "email": "lbryant@example.org", "currency": "SOS", "location": "East Daniel", "country": "Myanmar", "payment_method": "Foreign Bank Transfer", "product_id": "9b5847bf-c7fd-4acb-897e-f805442df25d", "product_category": "Pet Supplies", "quantity": 1, "discount": 51, "tax": 69, "shipping_cost": 80, "total_cost": 10658.73}'
#
#
# nomor pesan ke: 19
# Data_Transaksi_Keuangan_E-commerce:0:19: key=b'bc461877-9f17-4827-a2f3-5f91017965ca' value=b'{"transaction_id": "bc461877-9f17-4827-a2f3-5f91017965ca", "timestamp": "2024-02-18T15:35:50", "user_id": "07b8cf22-118c-43a2-91b4-c98b289e1784", "merchant_id": "5198af00-cbd9-4e4f-81d3-a4d05b713854", "amount": 82347.46, "age": 44, "gender": "Male", "phone_number": "6692322301", "email": "lawsoncaroline@example.com", "currency": "HRK", "location": "Fernandezmouth", "country": "Gabon", "payment_method": "Credit Card", "product_id": "ddf65de2-092b-40a5-b104-40d0891a8582", "product_category": "Hobbies and Collectibles", "quantity": 48, "discount": 46, "tax": 9, "shipping_cost": 32, "total_cost": 82342.46}'
#
#
# nomor pesan ke: 20
# Data_Transaksi_Keuangan_E-commerce:0:20: key=b'579e7d1c-d7e0-4b2d-abad-ff0ddf7d0ff5' value=b'{"transaction_id": "579e7d1c-d7e0-4b2d-abad-ff0ddf7d0ff5", "timestamp": "2024-10-27T17:46:27", "user_id": "b77f9534-10be-4751-bacc-4e1099b32433", "merchant_id": "e2d08b73-5469-4815-bc79-b1d473f4e307", "amount": 63552.86, "age": 19, "gender": "Male", "phone_number": "(886)682-4598x07483", "email": "coryrussell@example.org", "currency": "BRL", "location": "Popeberg", "country": "Iran", "payment_method": "Foreign Bank Transfer", "product_id": "846af3cc-4887-41fc-94b1-2c3c0f8c6a7f", "product_category": "Kitchen and Cooking Supplies", "quantity": 43, "discount": 53, "tax": 64, "shipping_cost": 63, "total_cost": 63626.86}'
#
#
# nomor pesan ke: 21
# Data_Transaksi_Keuangan_E-commerce:0:21: key=b'2db3cedf-fe72-494c-897a-5ccc6fb8de11' value=b'{"transaction_id": "2db3cedf-fe72-494c-897a-5ccc6fb8de11", "timestamp": "2024-01-21T22:55:29", "user_id": "72346a6e-4e5e-4bd8-b375-3b8127c32a15", "merchant_id": "93d0aa47-fade-4f36-a947-7309ddf80490", "amount": 93226.21, "age": 57, "gender": "Male", "phone_number": "(168)974-5447", "email": "jwaller@example.org", "currency": "TVD", "location": "Tracyland", "country": "Macao", "payment_method": "PayPal", "product_id": "7a5d37ce-4025-4925-82b2-ffc6d7e1a8ed", "product_category": "Pet Supplies", "quantity": 18, "discount": 11, "tax": 79, "shipping_cost": 89, "total_cost": 93383.21}'
#
#
# nomor pesan ke: 22
# Data_Transaksi_Keuangan_E-commerce:0:22: key=b'8b1d6140-c4af-4eb2-a02e-13e6772e942a' value=b'{"transaction_id": "8b1d6140-c4af-4eb2-a02e-13e6772e942a", "timestamp": "2024-08-20T07:16:57", "user_id": "95aeaec4-f2a3-475c-bfad-30b05b1803ab", "merchant_id": "fe2269f6-8328-4cc6-b4f9-7b927089e2a0", "amount": 4449.73, "age": 42, "gender": "Male", "phone_number": "304.686.2160x98845", "email": "lambertjohn@example.com", "currency": "XCD", "location": "Lake Lisaview", "country": "American Samoa", "payment_method": "PayPal", "product_id": "831fc8e1-f92b-4e33-bfe9-3929f3ff3877", "product_category": "Home and Furniture", "quantity": 15, "discount": 73, "tax": 92, "shipping_cost": 35, "total_cost": 4503.73}'
#
#
# nomor pesan ke: 23
# Data_Transaksi_Keuangan_E-commerce:0:23: key=b'05035c9a-803c-4c23-a525-d1d98b84887e' value=b'{"transaction_id": "05035c9a-803c-4c23-a525-d1d98b84887e", "timestamp": "2024-05-09T10:17:45", "user_id": "a138cdfc-80cc-41f2-b48e-8fd4a0db7d7d", "merchant_id": "eff66b52-dd67-487a-abaa-765790db9634", "amount": 93040.08, "age": 19, "gender": "Female", "phone_number": "(007)620-1252x35050", "email": "julia14@example.org", "currency": "UYU", "location": "North Elizabeth", "country": "Switzerland", "payment_method": "Credit Card", "product_id": "b034fa15-e513-45f3-9f14-358a8f71cd79", "product_category": "Kitchen and Cooking Supplies", "quantity": 2, "discount": 20, "tax": 48, "shipping_cost": 89, "total_cost": 93157.08}'
#
#
# nomor pesan ke: 24
# Data_Transaksi_Keuangan_E-commerce:0:24: key=b'dda84a0d-0667-4fc1-a562-c847b61c9f7f' value=b'{"transaction_id": "dda84a0d-0667-4fc1-a562-c847b61c9f7f", "timestamp": "2024-02-06T14:57:23", "user_id": "c5f42364-39b6-4872-b7d9-56fd498965a0", "merchant_id": "3d046ed1-09fe-4ad9-8d9a-08e9543466f5", "amount": 91870.28, "age": 41, "gender": "Female", "phone_number": "+1-349-850-4937", "email": "walkermichelle@example.com", "currency": "JOD", "location": "South Joshua", "country": "Singapore", "payment_method": "Credit Card", "product_id": "83a05d7e-5fca-4939-82a3-7cdcc1b40d7b", "product_category": "Office and School Supplies", "quantity": 17, "discount": 85, "tax": 19, "shipping_cost": 51, "total_cost": 91855.28}'
#
#
# nomor pesan ke: 25
# Data_Transaksi_Keuangan_E-commerce:0:25: key=b'1c9f5f67-7964-4ade-b7c3-60b364863014' value=b'{"transaction_id": "1c9f5f67-7964-4ade-b7c3-60b364863014", "timestamp": "2024-03-28T15:47:28", "user_id": "08f97073-7ee7-4867-a59b-0a874e7ec56f", "merchant_id": "5600d344-de65-4b0c-8aff-d02abf46c669", "amount": 72949.68, "age": 34, "gender": "Female", "phone_number": "+1-156-246-7471x395", "email": "lweber@example.org", "currency": "NOK", "location": "Gregoryburgh", "country": "Slovenia", "payment_method": "Credit Card", "product_id": "b5096c7d-96f9-46bf-a902-97e05ca78f96", "product_category": "Pet Supplies", "quantity": 12, "discount": 35, "tax": 57, "shipping_cost": 27, "total_cost": 72998.68}'
#
#
# nomor pesan ke: 26
# Data_Transaksi_Keuangan_E-commerce:0:26: key=b'45a644d8-0350-4aa5-b38f-2bc743bd7250' value=b'{"transaction_id": "45a644d8-0350-4aa5-b38f-2bc743bd7250", "timestamp": "2024-03-13T17:47:32", "user_id": "fb9c6a37-ca5c-478e-9036-43fbfbd2d9ba", "merchant_id": "090c4916-f293-4abc-a9c7-e65d713c675d", "amount": 32275.28, "age": 30, "gender": "Male", "phone_number": "+1-391-619-5298x905", "email": "jeffrey39@example.org", "currency": "BAM", "location": "Terriview", "country": "Benin", "payment_method": "Local Bank Transfer", "product_id": "f20c428c-9507-4ccd-b4db-6dc68906b158", "product_category": "Sports and Outdoors", "quantity": 12, "discount": 16, "tax": 51, "shipping_cost": 44, "total_cost": 32354.28}'
#
#
# nomor pesan ke: 27
# Data_Transaksi_Keuangan_E-commerce:0:27: key=b'72a87602-3cfc-42f4-bbc4-181bcab8a0bf' value=b'{"transaction_id": "72a87602-3cfc-42f4-bbc4-181bcab8a0bf", "timestamp": "2024-08-04T19:09:07", "user_id": "2bcd6892-dc16-4208-b2a7-74b76c82d72e", "merchant_id": "7a3c6bbe-6ac8-4b5a-8004-f79bdc0137d1", "amount": 51216.75, "age": 53, "gender": "Female", "phone_number": "354-665-2990", "email": "amber03@example.org", "currency": "KMF", "location": "West Craigborough", "country": "Montserrat", "payment_method": "PayPal", "product_id": "d05c3c24-aba5-4a86-8693-919993d554b7", "product_category": "Automotive", "quantity": 49, "discount": 58, "tax": 78, "shipping_cost": 3, "total_cost": 51239.75}'
#
#
# nomor pesan ke: 28
# Data_Transaksi_Keuangan_E-commerce:0:28: key=b'f25dd97c-c26a-4460-90ef-55118e6a7208' value=b'{"transaction_id": "f25dd97c-c26a-4460-90ef-55118e6a7208", "timestamp": "2024-09-09T04:03:13", "user_id": "65f8964a-25c3-4fd3-a7f6-8705d1c46e1b", "merchant_id": "fbc642d1-8791-4946-83c8-b789435edc94", "amount": 42381.26, "age": 28, "gender": "Male", "phone_number": "266-881-9630x420", "email": "daniel28@example.net", "currency": "KMF", "location": "Thomasmouth", "country": "Saint Vincent and the Grenadines", "payment_method": "Foreign Bank Transfer", "product_id": "52078f84-0efb-47ef-b74f-a32ab79bae28", "product_category": "Home and Furniture", "quantity": 46, "discount": 76, "tax": 72, "shipping_cost": 22, "total_cost": 42399.26}'
#
#
# nomor pesan ke: 29
# Data_Transaksi_Keuangan_E-commerce:0:29: key=b'a62adfbe-4b80-4593-96ce-9a42f830ca7f' value=b'{"transaction_id": "a62adfbe-4b80-4593-96ce-9a42f830ca7f", "timestamp": "2024-03-03T14:35:18", "user_id": "fae3015a-0b73-448f-9522-31f5466d3511", "merchant_id": "c581e7a1-5fba-40f3-a0e9-b2fc203cb92a", "amount": 33624.03, "age": 38, "gender": "Male", "phone_number": "001-226-673-5146x350", "email": "jesse15@example.net", "currency": "AMD", "location": "Sanchezfurt", "country": "Micronesia", "payment_method": "Foreign Bank Transfer", "product_id": "73a2d44f-7db0-4081-9c1a-6b519692d1fb", "product_category": "Digital Products and Services", "quantity": 8, "discount": 91, "tax": 74, "shipping_cost": 85, "total_cost": 33692.03}'
#
#
# nomor pesan ke: 30
# Data_Transaksi_Keuangan_E-commerce:0:30: key=b'76e6c418-2406-46df-bfe3-e690503f56e8' value=b'{"transaction_id": "76e6c418-2406-46df-bfe3-e690503f56e8", "timestamp": "2024-10-23T10:52:38", "user_id": "76726316-6f78-4d6d-93e2-962d14503f13", "merchant_id": "4cf14e5a-1834-4531-b895-e0af89f1c245", "amount": 95948.19, "age": 51, "gender": "Female", "phone_number": "140-830-6292", "email": "corygarcia@example.net", "currency": "RON", "location": "West Marktown", "country": "Korea", "payment_method": "Foreign Bank Transfer", "product_id": "f6dbcce0-8e32-4108-a805-ece31f8e2b14", "product_category": "Office and School Supplies", "quantity": 8, "discount": 57, "tax": 88, "shipping_cost": 90, "total_cost": 96069.19}'
#
#
# nomor pesan ke: 31
# Data_Transaksi_Keuangan_E-commerce:0:31: key=b'0b08c528-8d73-4d1f-8019-1b8bf579e58b' value=b'{"transaction_id": "0b08c528-8d73-4d1f-8019-1b8bf579e58b", "timestamp": "2024-03-08T13:47:50", "user_id": "87ffc036-c3ba-4b6e-9378-83d4c86554ed", "merchant_id": "5587abde-61c8-431d-a23e-56e674332d74", "amount": 30459.19, "age": 35, "gender": "Female", "phone_number": "(986)183-8712", "email": "spencerrogers@example.org", "currency": "INR", "location": "Garnerfurt", "country": "Lebanon", "payment_method": "Foreign Bank Transfer", "product_id": "6eb133ac-6092-48ab-bd1e-ed945e44f590", "product_category": "Hobbies and Collectibles", "quantity": 45, "discount": 81, "tax": 17, "shipping_cost": 98, "total_cost": 30493.19}'
#
#
# nomor pesan ke: 32
# Data_Transaksi_Keuangan_E-commerce:0:32: key=b'ef526592-cbcd-4060-969c-cd49aa108bb9' value=b'{"transaction_id": "ef526592-cbcd-4060-969c-cd49aa108bb9", "timestamp": "2024-08-21T22:35:09", "user_id": "0e36f252-c075-4a64-852a-3f88c0350e00", "merchant_id": "994068f8-7f9c-421f-a832-fe9b33448aac", "amount": 68313.19, "age": 40, "gender": "Male", "phone_number": "657.570.4765x050", "email": "brownsarah@example.com", "currency": "JMD", "location": "East Melissa", "country": "Bangladesh", "payment_method": "Credit Card", "product_id": "6f39163f-e39d-46fb-8458-8cb8fcd4fcaf", "product_category": "Sports and Outdoors", "quantity": 3, "discount": 96, "tax": 83, "shipping_cost": 24, "total_cost": 68324.19}'
#
#
# nomor pesan ke: 33
# Data_Transaksi_Keuangan_E-commerce:0:33: key=b'cbf6dd1c-b7d0-41fc-afed-1278750b2512' value=b'{"transaction_id": "cbf6dd1c-b7d0-41fc-afed-1278750b2512", "timestamp": "2024-05-19T17:08:09", "user_id": "174c0793-ab02-4440-8aa7-028fb243011a", "merchant_id": "87458f1e-cedc-48c6-8157-b9d1b2b7edb8", "amount": 74428.11, "age": 50, "gender": "Female", "phone_number": "(576)367-9846x856", "email": "christopher40@example.com", "currency": "PAB", "location": "North David", "country": "Mayotte", "payment_method": "Credit Card", "product_id": "8cdf82a7-58db-4562-b0d3-d6a963dbda66", "product_category": "Health and Beauty", "quantity": 27, "discount": 71, "tax": 73, "shipping_cost": 65, "total_cost": 74495.11}'
#
#
# nomor pesan ke: 34
# Data_Transaksi_Keuangan_E-commerce:0:34: key=b'cc462876-a691-4c52-826c-daced826c6de' value=b'{"transaction_id": "cc462876-a691-4c52-826c-daced826c6de", "timestamp": "2024-07-30T23:52:04", "user_id": "ab7165a4-9b9b-4182-935c-c293c40bc6b9", "merchant_id": "a032cc6b-4653-42f4-b705-dbefa0424736", "amount": 47813.64, "age": 35, "gender": "Female", "phone_number": "363.585.9206x9671", "email": "hernandezkyle@example.org", "currency": "AZN", "location": "New Tonyfort", "country": "Djibouti", "payment_method": "Credit Card", "product_id": "96fe8bff-5ee0-4871-bf5b-b1484843d238", "product_category": "Sports and Outdoors", "quantity": 41, "discount": 74, "tax": 96, "shipping_cost": 14, "total_cost": 47849.64}'
#
#
# nomor pesan ke: 35
# Data_Transaksi_Keuangan_E-commerce:0:35: key=b'8bdb09a0-ca3a-4987-85c3-66323c29f262' value=b'{"transaction_id": "8bdb09a0-ca3a-4987-85c3-66323c29f262", "timestamp": "2024-01-23T04:24:57", "user_id": "109b3ff8-ae4b-4361-8228-44297df92d5d", "merchant_id": "9a6c7a94-a218-4b0b-8dca-cd9240ef56d1", "amount": 6980.96, "age": 27, "gender": "Female", "phone_number": "1473291685", "email": "kingalex@example.net", "currency": "BAM", "location": "Larsonfort", "country": "Sierra Leone", "payment_method": "Local Bank Transfer", "product_id": "6c711f5e-db49-40a7-b14f-07b3ecc71f83", "product_category": "Fashion and Accessories", "quantity": 14, "discount": 26, "tax": 53, "shipping_cost": 82, "total_cost": 7089.96}'
#
#
# nomor pesan ke: 36
# Data_Transaksi_Keuangan_E-commerce:0:36: key=b'ef187f7e-1efe-465d-befc-d7b61edbc3da' value=b'{"transaction_id": "ef187f7e-1efe-465d-befc-d7b61edbc3da", "timestamp": "2024-02-03T14:38:41", "user_id": "338bec9a-5993-46ab-92da-710404a027ee", "merchant_id": "92fa1129-5a87-4c07-8174-7727841b6c1d", "amount": 13775.87, "age": 61, "gender": "Male", "phone_number": "808.491.1078x042", "email": "whitelisa@example.org", "currency": "SZL", "location": "Michaelbury", "country": "Andorra", "payment_method": "PayPal", "product_id": "d6b88e0f-a060-4570-944f-0a588f51257c", "product_category": "Baby and Kids Products", "quantity": 28, "discount": 50, "tax": 67, "shipping_cost": 99, "total_cost": 13891.87}'
#
#
# nomor pesan ke: 37
# Data_Transaksi_Keuangan_E-commerce:0:37: key=b'ca430694-bdb4-430b-8b6b-a898f393e4fd' value=b'{"transaction_id": "ca430694-bdb4-430b-8b6b-a898f393e4fd", "timestamp": "2024-04-27T06:15:39", "user_id": "26808361-116d-4312-b8ed-2f2b6463ff12", "merchant_id": "fbdb5bc6-0eb4-4e3a-b025-69cf81faeb58", "amount": 98084.92, "age": 54, "gender": "Female", "phone_number": "001-342-029-8893x91791", "email": "oliviahansen@example.org", "currency": "MRO", "location": "Port Alyssamouth", "country": "Vanuatu", "payment_method": "PayPal", "product_id": "2565fd53-c4a5-41e1-be98-cc9de32263ef", "product_category": "Electronics and Gadgets", "quantity": 26, "discount": 65, "tax": 86, "shipping_cost": 14, "total_cost": 98119.92}'
#
#
# nomor pesan ke: 38
# Data_Transaksi_Keuangan_E-commerce:0:38: key=b'f08cd620-9ec5-4e3b-a4c0-5689df1c38d8' value=b'{"transaction_id": "f08cd620-9ec5-4e3b-a4c0-5689df1c38d8", "timestamp": "2024-09-04T11:42:52", "user_id": "cb7e10a1-591d-478a-b324-35617f7900c5", "merchant_id": "07537cfe-2297-45e6-b043-eccf759b37b2", "amount": 59244.26, "age": 33, "gender": "Male", "phone_number": "+1-731-142-1575", "email": "richardperez@example.com", "currency": "TTD", "location": "North Rodney", "country": "Cook Islands", "payment_method": "Credit Card", "product_id": "32233cfc-c05a-4dd8-bb9a-0fe5a899d52c", "product_category": "Office and School Supplies", "quantity": 44, "discount": 46, "tax": 37, "shipping_cost": 4, "total_cost": 59239.26}'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 count = 0  # Inisialisasi penghitung pesan
# ----> 3 for message in consumer:
#       4     print("nomor pesan ke:", count)
#       5     # Cetak detail pesan
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File /opt/conda/lib/python3.10/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/conda/lib/python3.10/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /opt/conda/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:

# %%
consumer = KafkaConsumer(group_id='consumer-group',
                         bootstrap_servers=[f'{kafka_host}:9092'],
                         value_deserializer=lambda m: json.loads(m.decode('ascii')),
                         auto_offset_reset='earliest',
                         enable_auto_commit=False
                        )

# %%
#membaca sesuai partisi 1
consumer.assign([TopicPartition(kafka_topic_partition, 0)])
consumer.seek_to_beginning()

count = 1  # Inisialisasi penghitung pesan

for message in consumer:
    print("nomor pesan ke:", count)
    # Cetak detail pesan
    print("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                         message.offset, message.key,
                                         message.value))
    
    # Tambah penghitung setiap kali pesan diterima
    count += 1
    # Cetak jumlah total pesan setelah selesai (atau di bagian lain sesuai kebutuhan)
    print("\n")

# %%
#membaca sesuai partisi 2
consumer.assign([TopicPartition(kafka_topic_partition, 1)])

count = 1  # Inisialisasi penghitung pesan

for message in consumer:
    print("nomor pesan ke:", count)
    # Cetak detail pesan
    print("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                         message.offset, message.key,
                                         message.value))
    
    # Tambah penghitung setiap kali pesan diterima
    count += 1
    # Cetak jumlah total pesan setelah selesai (atau di bagian lain sesuai kebutuhan)
    print("\n")

# %%
#membaca sesuai partisi 3
consumer.assign([TopicPartition(kafka_topic_partition, 2)])

count = 1  # Inisialisasi penghitung pesan

for message in consumer:
    print("nomor pesan ke:", count)
    # Cetak detail pesan
    print("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                         message.offset, message.key,
                                         message.value))
    
    # Tambah penghitung setiap kali pesan diterima
    count += 1
    # Cetak jumlah total pesan setelah selesai (atau di bagian lain sesuai kebutuhan)
    print("\n")

# %%
#membaca sesuai partisi 4
consumer.assign([TopicPartition(kafka_topic_partition, 3)])

count = 1  # Inisialisasi penghitung pesan

for message in consumer:
    print("nomor pesan ke:", count)
    # Cetak detail pesan
    print("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                         message.offset, message.key,
                                         message.value))
    
    # Tambah penghitung setiap kali pesan diterima
    count += 1
    # Cetak jumlah total pesan setelah selesai (atau di bagian lain sesuai kebutuhan)
    print("\n")

# %%
#membaca sesuai partisi 5
consumer.assign([TopicPartition(kafka_topic_partition, 4)])

count = 1  # Inisialisasi penghitung pesan

for message in consumer:
    print("nomor pesan ke:", count)
    # Cetak detail pesan
    print("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                         message.offset, message.key,
                                         message.value))
    
    # Tambah penghitung setiap kali pesan diterima
    count += 1
    # Cetak jumlah total pesan setelah selesai (atau di bagian lain sesuai kebutuhan)
    print("\n")

# %% [markdown]
# ## Save data to json

# %%
#Transaksi_Keuangan_E_commerce
# Konfigurasi Kafka
consumer.assign([
    TopicPartition(kafka_topic_partition, 0),
    TopicPartition(kafka_topic_partition, 1),
    TopicPartition(kafka_topic_partition, 2),
    TopicPartition(kafka_topic_partition, 3),
    TopicPartition(kafka_topic_partition, 4)
])

consumer.seek_to_beginning()

# Direktori dan file untuk menyimpan data
#json_directory = "/resource/KSQLDB_Kafka/Data"
#json_file_path = os.path.join(json_directory, "Data_Transaksi_Keuangan_E_commerce.json")

# Proses pesan dari Kafka
for message in consumer:
    print("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                         message.offset, message.key,
                                         message.value))
    print("\n")

# Menyimpan pesan sebagai JSON
    try:
        # Cek apakah message.value berupa bytes atau dict
        if isinstance(message.value, bytes):
            value = message.value.decode('utf-8')  # Decode jika tipe data bytes
        else:
            value = message.value  # Jika sudah berupa dict atau tipe lain, langsung gunakan

        # Simpan pesan sebagai JSON
        with open("Transaksi_Keuangan_E_commerce.json", 'w') as json_file:
            json.dump({
                "topic": message.topic,
                "partition": message.partition,
                "offset": message.offset,
                "key": message.key.decode('utf-8') if message.key else None,
                "value": value
            }, json_file, indent=4)
        
        print("Data berhasil disimpan ke JSON.")
    except Exception as e:
        print(f"Gagal menyimpan data ke JSON karena: {e}")

# %%
#MERCHANT_REVENUE
# Konfigurasi Kafka
kafka_topic_1 ="MERCHANT_REVENUE"
consumer.assign([
    TopicPartition(kafka_topic_1, 0),
    TopicPartition(kafka_topic_1, 1),
    TopicPartition(kafka_topic_1, 2),
    TopicPartition(kafka_topic_1, 3),
    TopicPartition(kafka_topic_1, 4)
])

consumer.seek_to_beginning()

# Direktori dan file untuk menyimpan data
#json_directory = "/resource/KSQLDB_Kafka/Data"
#json_file_path = os.path.join(json_directory, "Data_Transaksi_Keuangan_E_commerce.json")

# Proses pesan dari Kafka
for message in consumer:
    print("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                         message.offset, message.key,
                                         message.value))
    print("\n")

# Menyimpan pesan sebagai JSON
    try:
        # Cek apakah message.value berupa bytes atau dict
        if isinstance(message.value, bytes):
            value = message.value.decode('utf-8')  # Decode jika tipe data bytes
        else:
            value = message.value  # Jika sudah berupa dict atau tipe lain, langsung gunakan

        # Simpan pesan sebagai JSON
        with open("Transaksi_Keuangan_E_commerce.json", 'w') as json_file:
            json.dump({
                "topic": message.topic,
                "partition": message.partition,
                "offset": message.offset,
                "key": message.key.decode('utf-8') if message.key else None,
                "value": value
            }, json_file, indent=4)
        
        print("Data berhasil disimpan ke JSON.")
    except Exception as e:
        print(f"Gagal menyimpan data ke JSON karena: {e}")

# %%
#AVG_AGE_PER_CATEGORY
# Konfigurasi Kafka
kafka_topic_2 ="AVG_AGE_PER_CATEGORY"
consumer.assign([
    TopicPartition(kafka_topic_2, 0),
    TopicPartition(kafka_topic_2, 1),
    TopicPartition(kafka_topic_2, 2),
    TopicPartition(kafka_topic_2, 3),
    TopicPartition(kafka_topic_2, 4)
])

consumer.seek_to_beginning()

# Direktori dan file untuk menyimpan data
#json_directory = "/resource/KSQLDB_Kafka/Data"
#json_file_path = os.path.join(json_directory, "Data_Transaksi_Keuangan_E_commerce.json")

# Proses pesan dari Kafka
for message in consumer:
    print("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                         message.offset, message.key,
                                         message.value))
    print("\n")

# Menyimpan pesan sebagai JSON
    try:
        # Cek apakah message.value berupa bytes atau dict
        if isinstance(message.value, bytes):
            value = message.value.decode('utf-8')  # Decode jika tipe data bytes
        else:
            value = message.value  # Jika sudah berupa dict atau tipe lain, langsung gunakan

        # Simpan pesan sebagai JSON
        with open("Transaksi_Keuangan_E_commerce.json", 'w') as json_file:
            json.dump({
                "topic": message.topic,
                "partition": message.partition,
                "offset": message.offset,
                "key": message.key.decode('utf-8') if message.key else None,
                "value": value
            }, json_file, indent=4)
        
        print("Data berhasil disimpan ke JSON.")
    except Exception as e:
        print(f"Gagal menyimpan data ke JSON karena: {e}")

# %%
#PAYMENT_METHOD_COUNTS
# Konfigurasi Kafka
kafka_topic_3 ="PAYMENT_METHOD_COUNTS"
consumer.assign([
    TopicPartition(kafka_topic_3, 0),
    TopicPartition(kafka_topic_3, 1),
    TopicPartition(kafka_topic_3, 2),
    TopicPartition(kafka_topic_3, 3),
    TopicPartition(kafka_topic_3, 4)
])

consumer.seek_to_beginning()

# Direktori dan file untuk menyimpan data
#json_directory = "/resource/KSQLDB_Kafka/Data"
#json_file_path = os.path.join(json_directory, "Data_Transaksi_Keuangan_E_commerce.json")

# Proses pesan dari Kafka
for message in consumer:
    print("%s:%d:%d: key=%s value=%s" % (message.topic, message.partition,
                                         message.offset, message.key,
                                         message.value))
    print("\n")

# Menyimpan pesan sebagai JSON
    try:
        # Cek apakah message.value berupa bytes atau dict
        if isinstance(message.value, bytes):
            value = message.value.decode('utf-8')  # Decode jika tipe data bytes
        else:
            value = message.value  # Jika sudah berupa dict atau tipe lain, langsung gunakan

        # Simpan pesan sebagai JSON
        with open("Transaksi_Keuangan_E_commerce.json", 'w') as json_file:
            json.dump({
                "topic": message.topic,
                "partition": message.partition,
                "offset": message.offset,
                "key": message.key.decode('utf-8') if message.key else None,
                "value": value
            }, json_file, indent=4)
        
        print("Data berhasil disimpan ke JSON.")
    except Exception as e:
        print(f"Gagal menyimpan data ke JSON karena: {e}")
